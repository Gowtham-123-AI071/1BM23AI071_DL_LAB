# %%
import numpy as np
import matplotlib.pyplot as plt

class XORNeuralNetwork:
    def __init__(self, learning_rate=0.5):
        self.learning_rate = learning_rate
        self.weights_input_hidden = np.random.uniform(-1, 1, (2, 2))
        self.weights_hidden_output = np.random.uniform(-1, 1, (2, 1))

        self.bias_hidden = np.random.uniform(-1, 1, (1, 2))
        self.bias_output = np.random.uniform(-1, 1, (1, 1))

        self.error_history = []

    def sigmoid(self, x):
        x=np.clip(x,-500,500)
        return 1 / (1 + np.exp(-x))

    def sigmoid_derivative(self, x):
        return x * (1 - x)

    def forward_pass(self, X):
        self.hidden_input = np.dot(X, self.weights_input_hidden) + self.bias_hidden
        self.hidden_output = self.sigmoid(self.hidden_input)

        self.final_input = np.dot(self.hidden_output, self.weights_hidden_output) + self.bias_output
        self.final_output = self.sigmoid(self.final_input)
        return self.final_output
    def backward_pass(self,X,y,final_output):
        m=X.shape[0]
        output_error = y - self.final_output
        output_delta = output_error * self.sigmoid_derivative(self.final_output)

       
        hidden_error = output_delta.dot(self.weights_hidden_output.T)
        hidden_delta = hidden_error * self.sigmoid_derivative(self.hidden_output)
        
        self.weights_hidden_output += self.hidden_output.T.dot(output_delta) * self.learning_rate
        self.bias_output += np.sum(output_delta, axis=0, keepdims=True) * self.learning_rate

        self.weights_input_hidden += self.input.T.dot(hidden_delta) * self.learning_rate
        self.bias_hidden += np.sum(hidden_delta, axis=0, keepdims=True) * self.learning_rate
        
        train(self,X,y, epochs=10000, print_every=1000):
            
            for epoch in range (epochs):
                predicted_output=self.forward_pass(X)
                
                mse=np.mean((y-predicted_output)**2)
                
                self.backward_pass(X,y,predicted_output)
                
                if epoch% print_every ==0:
                    print(f"Epoch:{epoch},Error:{mse:.6f}")
                    
def predict(self,x):
    return self.forward_pass(X)

def print_results(self,X,y):
    predictions =self.predict(X)
    print("\nfinal results")
    print("input-> target|predicted->rounded")
    print("-"*40)
    for i in range(len(X)):
        predicted_val=predictions[i][0]
        rounded_val=round(predicted_val)
        print(f"{X[i]}->{y[i][0]:.0f}|{ predicted_val:.4f}->{rounded_val}")
        
    rounded_predictions=np.round(predictions)
    accuracy=np.mean(rounded_predictions==y)*100
    print(f"\nAccuracy:{    accuracy:.1f}%")
    
main():

X=np.array([[0,0],[0,1],[1,0][1,1]])
y=np.array([[0],[1],[1],[0]])

nn=XORNeuralNetwork(learning_rate=1.0)
nn.train(X,y,epochs=10000,print_every=2000)

nn.print_results(X,y)


plt.figure(figsize=(10,6))
plt.plot(nn.error_history)
plt.title("train error over time")
plt.xlabel("epoch")
plt.ylabel("MSE")
plt.yscale('log')
plt.show()

print(f"\nlearned wegiths")

# %%
import numpy as np
import matplotlib.pyplot as plt

class XORNeuralNetwork:
    def __init__(self, learning_rate=0.5):
        self.learning_rate = learning_rate
        self.weights_input_hidden = np.random.uniform(-1, 1, (2, 2))
        self.weights_hidden_output = np.random.uniform(-1, 1, (2, 1))
        self.bias_hidden = np.random.uniform(-1, 1, (1, 2))
        self.bias_output = np.random.uniform(-1, 1, (1, 1))
        self.error_history = []

    def sigmoid(self, x):
        x = np.clip(x, -500, 500)
        return 1 / (1 + np.exp(-x))

    def sigmoid_derivative(self, x):
        return x * (1 - x)

    def forward_pass(self, X):
        self.input = X
        self.hidden_input = np.dot(X, self.weights_input_hidden) + self.bias_hidden
        self.hidden_output = self.sigmoid(self.hidden_input)
        self.final_input = np.dot(self.hidden_output, self.weights_hidden_output) + self.bias_output
        self.final_output = self.sigmoid(self.final_input)
        return self.final_output

    def backward_pass(self, X, y):
        output_error = y - self.final_output
        output_delta = output_error * self.sigmoid_derivative(self.final_output)

        hidden_error = output_delta.dot(self.weights_hidden_output.T)
        hidden_delta = hidden_error * self.sigmoid_derivative(self.hidden_output)

        self.weights_hidden_output += self.hidden_output.T.dot(output_delta) * self.learning_rate
        self.bias_output += np.sum(output_delta, axis=0, keepdims=True) * self.learning_rate

        self.weights_input_hidden += self.input.T.dot(hidden_delta) * self.learning_rate
        self.bias_hidden += np.sum(hidden_delta, axis=0, keepdims=True) * self.learning_rate

        mse = np.mean(output_error**2)
        self.error_history.append(mse)

    def train(self, X, y, epochs=10000, print_every=1000):
        for epoch in range(epochs):
            predicted_output = self.forward_pass(X)
            self.backward_pass(X, y)
            if epoch % print_every == 0:
                mse = self.error_history[-1]
                print(f"Epoch: {epoch}, Error: {mse:.6f}")

    def predict(self, X):
        return self.forward_pass(X)

    def print_results(self, X, y):
        predictions = self.predict(X)
        print("\nFinal results")
        print("Input -> Target | Predicted -> Rounded")
        print("-" * 40)
        for i in range(len(X)):
            predicted_val = predictions[i][0]
            rounded_val = round(predicted_val)
            print(f"{X[i]} -> {y[i][0]:.0f} | {predicted_val:.4f} -> {rounded_val}")
        rounded_predictions = np.round(predictions)
        accuracy = np.mean(rounded_predictions == y) * 100
        print(f"\nAccuracy: {accuracy:.1f}%")

    def print_weights(self):
        print("\nLearned weights:")
        print("Weights Input to Hidden:\n", self.weights_input_hidden)
        print("Bias Hidden:\n", self.bias_hidden)
        print("Weights Hidden to Output:\n", self.weights_hidden_output)
        print("Bias Output:\n", self.bias_output)


def main():
    X = np.array([[0, 0],
                  [0, 1],
                  [1, 0],
                  [1, 1]])
    y = np.array([[0],
                  [1],
                  [1],
                  [0]])

    nn = XORNeuralNetwork(learning_rate=1.0)
    nn.train(X, y, epochs=10000, print_every=2000)
    nn.print_results(X, y)

    plt.figure(figsize=(10, 6))
    plt.plot(nn.error_history)
    plt.title("Training error over time")
    plt.xlabel("Epoch")
    plt.ylabel("MSE")
    plt.yscale('log')
    plt.grid(True)
    plt.show()

    nn.print_weights()

if __name__ == "__main__":
    main()
# Out:
# Epoch: 0, Error: 0.257738
# Epoch: 2000, Error: 0.000848
# Epoch: 4000, Error: 0.000365
# Epoch: 6000, Error: 0.000230
# Epoch: 8000, Error: 0.000167
#
# Final results
# Input -> Target | Predicted -> Rounded
# ----------------------------------------
# [0 0] -> 0 | 0.0115 -> 0
# [0 1] -> 1 | 0.9869 -> 1
# [1 0] -> 1 | 0.9892 -> 1
# [1 1] -> 0 | 0.0102 -> 0
#
# Accuracy: 100.0%
# Learned weights:
# Weights Input to Hidden:
#  [[ 6.50179612  5.88995324]
#  [-6.37740963 -6.088586  ]]
# Bias Hidden:
#  [[ 3.22370752 -3.16612895]]
# Weights Hidden to Output:
#  [[-9.98895624]
#  [10.4133932 ]]
# Bias Output:
#  [[4.7295972]]

# %%
#3 and 4
import numpy as np
import matplotlib.pyplot as plt

class XORNeuralNetwork:
    def __init__(self, learning_rate=0.5, hidden_neurons=3):
        self.learning_rate = learning_rate
        self.weights_input_hidden = np.random.uniform(-1, 1, (2, hidden_neurons))
        self.weights_hidden_output = np.random.uniform(-1, 1, (hidden_neurons, 1))
        self.bias_hidden = np.random.uniform(-1, 1, (1, hidden_neurons))
        self.bias_output = np.random.uniform(-1, 1, (1, 1))
        self.error_history = []

    def sigmoid(self, x):
        x = np.clip(x, -500, 500)
        return 1 / (1 + np.exp(-x))

    def sigmoid_derivative(self, x):
        return x * (1 - x)

    def forward_pass(self, X):
        self.input = X
        self.hidden_input = np.dot(X, self.weights_input_hidden) + self.bias_hidden
        self.hidden_output = self.sigmoid(self.hidden_input)
        self.final_input = np.dot(self.hidden_output, self.weights_hidden_output) + self.bias_output
        self.final_output = self.sigmoid(self.final_input)
        return self.final_output

    def backward_pass(self, X, y):
        output_error = y - self.final_output
        output_delta = output_error * self.sigmoid_derivative(self.final_output)

        hidden_error = output_delta.dot(self.weights_hidden_output.T)
        hidden_delta = hidden_error * self.sigmoid_derivative(self.hidden_output)

        self.weights_hidden_output += self.hidden_output.T.dot(output_delta) * self.learning_rate
        self.bias_output += np.sum(output_delta, axis=0, keepdims=True) * self.learning_rate

        self.weights_input_hidden += self.input.T.dot(hidden_delta) * self.learning_rate
        self.bias_hidden += np.sum(hidden_delta, axis=0, keepdims=True) * self.learning_rate

        mse = np.mean(output_error**2)
        self.error_history.append(mse)

    def train(self, X, y, epochs=5000, print_every=1000):
        for epoch in range(epochs):
            predicted_output = self.forward_pass(X)
            self.backward_pass(X, y)
            if epoch % print_every == 0:
                mse = self.error_history[-1]
                print(f"Epoch: {epoch}, Error: {mse:.6f}")

    def predict(self, X):
        return self.forward_pass(X)

    def print_results(self, X, y):
        predictions = self.predict(X)
        print("\nFinal results")
        print("Input -> Target | Predicted -> Rounded")
        print("-" * 40)
        for i in range(len(X)):
            predicted_val = predictions[i][0]
            rounded_val = round(predicted_val)
            print(f"{X[i]} -> {y[i][0]:.0f} | {predicted_val:.4f} -> {rounded_val}")
        rounded_predictions = np.round(predictions)
        accuracy = np.mean(rounded_predictions == y) * 100
        print(f"\nAccuracy: {accuracy:.1f}%")

    def print_weights(self):
        print("\nLearned weights:")
        print("Weights Input to Hidden:\n", self.weights_input_hidden)
        print("Bias Hidden:\n", self.bias_hidden)
        print("Weights Hidden to Output:\n", self.weights_hidden_output)
        print("Bias Output:\n", self.bias_output)

def main():
    X = np.array([[0, 0],
                  [0, 1],
                  [1, 0],
                  [1, 1]])
    y = np.array([[0],
                  [1],
                  [1],
                  [0]])

    nn = XORNeuralNetwork(learning_rate=1.0, hidden_neurons=3)
    nn.train(X, y, epochs=10000, print_every=2000)
    nn.print_results(X, y)

    plt.figure(figsize=(10, 6))
    plt.plot(nn.error_history)
    plt.title("Training error over time")
    plt.xlabel("Epoch")
    plt.ylabel("MSE")
    plt.yscale('log')
    plt.grid(True)
    plt.show()

    nn.print_weights()

if __name__ == "__main__":
    main()
# Out:
# Epoch: 0, Error: 0.262627
# Epoch: 2000, Error: 0.000765
# Epoch: 4000, Error: 0.000314
# Epoch: 6000, Error: 0.000195
# Epoch: 8000, Error: 0.000141
#
# Final results
# Input -> Target | Predicted -> Rounded
# ----------------------------------------
# [0 0] -> 0 | 0.0105 -> 0
# [0 1] -> 1 | 0.9913 -> 1
# [1 0] -> 1 | 0.9869 -> 1
# [1 1] -> 0 | 0.0091 -> 0
#
# Accuracy: 100.0%
# Learned weights:
# Weights Input to Hidden:
#  [[-4.93215708 -3.95100361 -6.50772457]
#  [ 4.71208417  3.85294155  6.56397753]]
# Bias Hidden:
#  [[-2.72234881 -2.37364862  3.20034794]]
# Weights Hidden to Output:
#  [[  7.08629929]
#  [  5.34775045]
#  [-10.5353185 ]]
# Bias Output:
#  [[4.68244772]]
